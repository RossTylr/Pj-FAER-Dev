# %% [markdown]
# # NB41 — EX-5 Treatment Yield Delegation Proof
#
# Delegates Y1+Y2 to treatment.py via yield from. Exception safety verified.
#
# **Build instructions:** See corresponding doc in `docs/`

# %% [markdown]
# ---
# ## Setup

# %%
# Dependencies
import numpy as np
import simpy
import networkx as nx
from collections import Counter
from dataclasses import dataclass, field
from typing import List, Optional, Dict, Any

print('Setup complete')

# %% [markdown]
# ---
# ## Implementation
#
# See `docs/` for detailed cell-by-cell instructions.
